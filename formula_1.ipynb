# %% [markdown]
# **Installing libraries**

# %%
import pandas as pd

# %% [markdown]
# **Importing files and dropping unnecessary columns**

# %% [markdown]
# *Race Data*

# %%
#All files will be read in this cell in their raw form
race_data = pd.read_csv(r'D:\Projects\Formula 1\f1db_csv\races.csv')

# %%
race_data.columns
# Out:
# Index(['raceId', 'year', 'round', 'circuitId', 'name', 'date', 'time', 'url',
#        'fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time',
#        'quali_date', 'quali_time', 'sprint_date', 'sprint_time'],
#       dtype='object')

# %%
columns = ['raceId','year','round','circuitId','name','date']

# %%
#race data
df_race = race_data[columns]

# %% [markdown]
# *Circuit Data*

# %%
circuit_data = pd.read_csv(r"D:\Projects\Formula 1\f1db_csv\circuits.csv")

# %%
circuit_data.columns
# Out:
# Index(['circuitId', 'circuitRef', 'name', 'location', 'country', 'lat', 'lng',
#        'alt', 'url'],
#       dtype='object')

# %%
columns = ['circuitId', 'name', 'location', 'country', 'lat', 'lng']

# %%
#circuit data
df_circuit = circuit_data[columns]

# %% [markdown]
# *Constructor Data*

# %%
cons_data = pd.read_csv(r"D:\Projects\Formula 1\f1db_csv\constructors.csv")

# %%
cons_data.columns
# Out:
# Index(['constructorId', 'constructorRef', 'name', 'nationality', 'url'], dtype='object')

# %%
columns = ['constructorId', 'name']

# %%
df_constructor = cons_data[columns]

# %% [markdown]
# *Driver Data*

# %%
driver_data = pd.read_csv(r"D:\Projects\Formula 1\f1db_csv\drivers.csv")

# %%
driver_data.columns
# Out:
# Index(['driverId', 'driverRef', 'number', 'code', 'forename', 'surname', 'dob',
#        'nationality', 'url'],
#       dtype='object')

# %%
columns = ['driverId', 'number', 'code', 'forename', 'surname', 'dob', 'nationality']

# %%
df_driver = driver_data[columns]

# %% [markdown]
# *Qualifying Data*

# %%
quali_data = pd.read_csv(r"D:\Projects\Formula 1\f1db_csv\qualifying.csv")

# %%
quali_data.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          1      18         1              1      22         1  1:26.572
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
quali_data.columns
# Out:
# Index(['qualifyId', 'raceId', 'driverId', 'constructorId', 'number',
#        'position', 'q1', 'q2', 'q3'],
#       dtype='object')

# %%
columns = ['qualifyId', 'raceId', 'driverId', 'constructorId', 'number', 'position']

# %%
df_quali = quali_data[columns]

# %%
driver_num = df_quali['number']

# %%
df_quali['driver_num'] = driver_num
# Out:
# C:\Users\femin\AppData\Local\Temp\ipykernel_18352\623012824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_quali['driver_num'] = driver_num

# %%
df_quali.drop(columns = 'number')
# Out:
#        qualifyId  raceId  driverId  constructorId  position  driver_num
# 0              1      18         1              1         1          22
# 1              2      18         9              2         2           4
# 2              3      18         5              1         3          23
# 3              4      18        13              6         4           2
# 4              5      18         2              2         5           3
# ...          ...     ...       ...            ...       ...         ...
# 10089      10147    1124       840            117        16          18
# 10090      10148    1124       842            214        17          10
# 10091      10149    1124       825            210        18          20
# 10092      10150    1124       858              3        19           2
# 10093      10151    1124       855             15        20          24
#
# [10094 rows x 6 columns]

# %% [markdown]
# *Sprint Results Data*

# %%
sprint_data = pd.read_csv(r"D:\Projects\Formula 1\f1db_csv\sprint_results.csv")

# %%
sprint_data.head()
# Out:
#    resultId  raceId  driverId  constructorId  number  grid position  \
# 0         1    1061       830              9      33     2        1
# 1         2    1061         1            131      44     1        2
# 2         3    1061       822            131      77     3        3
# 3         4    1061       844              6      16     4        4
# 4         5    1061       846              1       4     6        5
#
#   positionText  positionOrder  points  laps       time milliseconds  \
# 0            1              1       3    17  25:38.426      1538426
# 1            2              2       2    17     +1.430      1539856
# 2            3              3       1    17     +7.502      1545928
# 3            4              4       0    17    +11.278      1549704
# 4            5              5       0    17    +24.111      1562537
#
#   fastestLap fastestLapTime  statusId
# 0         14       1:30.013         1
# 1         17       1:29.937         1
# ...

# %%
driver_num = sprint_data['number']

# %%
sprint_data['driver_num'] = driver_num

# %%
sprint_data = sprint_data.drop(columns = 'number')

# %%
sprint_data.columns
# Out:
# Index(['resultId', 'raceId', 'driverId', 'constructorId', 'grid', 'position',
#        'positionText', 'positionOrder', 'points', 'laps', 'time',
#        'milliseconds', 'fastestLap', 'fastestLapTime', 'statusId',
#        'driver_num'],
#       dtype='object')

# %%
columns = ['resultId', 'raceId', 'driverId', 'constructorId', 'grid',
       'position', 'points', 'laps', 'time',
       'milliseconds', 'fastestLap', 'fastestLapTime', 
       'driver_num']

# %%
df_sprint = sprint_data[columns]

# %% [markdown]
# *Results Data*

# %%
results_data = pd.read_csv(r"D:\Projects\Formula 1\f1db_csv\results.csv")

# %%
driver_num = results_data['number']

# %%
results_data['driver_num'] = driver_num

# %%
results_data = results_data.drop(columns = 'number')

# %%
results_data.columns
# Out:
# Index(['resultId', 'raceId', 'driverId', 'constructorId', 'grid', 'position',
#        'positionText', 'positionOrder', 'points', 'laps', 'time',
#        'milliseconds', 'fastestLap', 'rank', 'fastestLapTime',
#        'fastestLapSpeed', 'statusId', 'driver_num'],
#       dtype='object')

# %%
results_data.head()
# Out:
#    resultId  raceId  driverId  constructorId  grid position positionText  \
# 0         1      18         1              1     1        1            1
# 1         2      18         2              2     5        2            2
# 2         3      18         3              3     7        3            3
# 3         4      18         4              4    11        4            4
# 4         5      18         5              1     3        5            5
#
#    positionOrder  points  laps         time milliseconds fastestLap rank  \
# 0              1    10.0    58  1:34:50.616      5690616         39    2
# 1              2     8.0    58       +5.478      5696094         41    3
# 2              3     6.0    58       +8.163      5698779         41    5
# 3              4     5.0    58      +17.181      5707797         58    7
# 4              5     4.0    58      +18.014      5708630         43    1
#
#   fastestLapTime fastestLapSpeed  statusId driver_num
# ...

# %%
columns = ['resultId', 'raceId', 'driverId', 'constructorId', 'grid', 'position', 'points', 'laps', 'time',
       'milliseconds', 'rank', 'fastestLapTime','driver_num']

# %%
df_results = results_data[columns]

# %% [markdown]
# *Pitstop Data*

# %%
pitstop_data = pd.read_csv(r"D:\Projects\Formula 1\f1db_csv\pit_stops.csv")

# %%
pitstop_data.head()
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
pitstop_data.columns
# Out:
# Index(['raceId', 'driverId', 'stop', 'lap', 'time', 'duration',
#        'milliseconds'],
#       dtype='object')

# %%
columns = ['raceId', 'driverId', 'lap', 'duration',
       'milliseconds']

# %%
df_pitstop = pitstop_data[columns]

# %% [markdown]
# *Driver Standings Data*

# %%
driver_stand_data = pd.read_csv(r"D:\Projects\Formula 1\f1db_csv\driver_standings.csv")

# %%
driver_stand_data.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
driver_stand_data = driver_stand_data.drop(columns = 'positionText')

# %%
df_driver_stand = driver_stand_data

# %% [markdown]
# *Constructor Standings Data*

# %%
cons_stand_data = pd.read_csv(r"D:\Projects\Formula 1\f1db_csv\constructor_standings.csv")

# %%
cons_stand_data = cons_stand_data.drop(columns = 'positionText')

# %%
df_cons_stand = cons_stand_data
